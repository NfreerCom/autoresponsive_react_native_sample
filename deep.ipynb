# %% [markdown]
# <a href="https://colab.research.google.com/github/NfreerCom/autoresponsive_react_native_sample/blob/master/deep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install finance-datareader

# %%
df_krx = fdr.StockListing('KRX')

# %%
import FinanceDataReader as fdr 
df = fdr.DataReader(symbol='005930', start='2020')
print(df)
df.head(10)
df['Close'].plot()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2020-01-02  55500  56000  55000  55200  12993228 -0.010753
# 2020-01-03  56000  56600  54900  55500  15422255  0.005435
# 2020-01-06  54900  55600  54600  55500  10278951  0.000000
# 2020-01-07  55700  56400  55600  55800  10009778  0.005405
# 2020-01-08  56200  57400  55900  56800  23501171  0.017921
# ...           ...    ...    ...    ...       ...       ...
# 2021-06-28  81700  82000  81600  81900  11578529  0.003676
# 2021-06-29  81900  82100  80800  81000  15744317 -0.010989
# 2021-06-30  81100  81400  80700  80700  13288643 -0.003704
# 2021-07-01  80500  80600  80000  80100  13382882 -0.007435
# 2021-07-02  80000  80400  79900  80000   8181692 -0.001248
#
# [373 rows x 6 columns]

# %%
df_krx = fdr.StockListing('KRX')
print(len(df_krx))
df_krx.head().plot()
# Out:
# 7129
